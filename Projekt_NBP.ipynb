# %% [markdown]
# # Analiza walut w obliczu Korona wirusa na świecie

# %% [markdown]
# # BigData Projekt - Hugo Czerniawski

# %%
import requests
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Import bibliotek

# %%
USD=requests.get("https://api.nbp.pl/api/exchangerates/rates/a/usd/2020-01-01/2020-06-11/")

usd_frame = pd.read_json(USD.content)
usd_rates = usd_frame.rates
usd_list=[index['mid'] for index in usd_rates]
plt.plot(usd_list)
plt.xticks(rotation=45)
plt.title("Kurs Dolara")
plt.xlabel("2020-01-01 do 2020-06-11")
plt.ylabel("Cena [Pln]")
plt.legend(["USD"])
plt.grid()

plt.show()

# %%
GBP=requests.get("https://api.nbp.pl/api/exchangerates/rates/a/gbp/2020-01-01/2020-06-11/")

gbp_frame = pd.read_json(GBP.content)
gbp_rates = gbp_frame.rates
gbp_list=[index['mid'] for index in gbp_rates]
plt.plot(gbp_list)
plt.xticks(rotation=45)
plt.title("Kurs Funta")
plt.xlabel("2020-01-01 do 2020-06-11")
plt.ylabel("Cena [Pln]")
plt.legend(["GBP"])
plt.grid()

plt.show()

# %%
EUR=requests.get("https://api.nbp.pl/api/exchangerates/rates/a/eur/2020-01-01/2020-06-11/")

eur_frame = pd.read_json(EUR.content)
eur_rates = eur_frame.rates
eur_list=[index['mid'] for index in eur_rates]
plt.plot(eur_list)
plt.xticks(rotation=45)
plt.title("Kurs Euro")
plt.xlabel("2020-01-01 do 2020-06-11")
plt.ylabel("Cena [Pln]")
plt.legend(["EUR"])
plt.grid()

plt.show()

# %%
JPY=requests.get("https://api.nbp.pl/api/exchangerates/rates/a/jpy/2020-01-01/2020-06-11/")

jpy_frame = pd.read_json(JPY.content)
jpy_rates = jpy_frame.rates
jpy_list=[index['mid'] for index in jpy_rates]
plt.plot(jpy_list)
plt.xticks(rotation=45)
plt.title("Kurs Jena")
plt.xlabel("2020-01-01 do 2020-06-11")
plt.ylabel("Cena [Pln]")
plt.legend(["JPY"])
plt.grid()

plt.show()

# %%
CHF=requests.get("https://api.nbp.pl/api/exchangerates/rates/a/chf/2020-01-01/2020-06-11/")

chf_frame = pd.read_json(CHF.content)
chf_rates = chf_frame.rates
chf_list=[index['mid'] for index in chf_rates]
plt.plot(chf_list)
plt.xticks(rotation=45)
plt.title("Kurs Franka Szwajcarskiego")
plt.xlabel("2020-01-01 do 2020-06-11")
plt.ylabel("Cena [Pln]")
plt.legend(["CHF"])
plt.grid()

plt.show()

# %%
NOK = requests.get("https://api.nbp.pl/api/exchangerates/rates/a/nok/2020-01-01/2020-06-11/")

nok_frame = pd.read_json(NOK.content)
nok_rates = nok_frame.rates
nok_list=[index['mid'] for index in nok_rates]
plt.plot(nok_list)
plt.xticks(rotation=45)
plt.title("Kurs Korony Norweskiej")
plt.xlabel("2020-01-01 do 2020-06-11")
plt.ylabel("Cena [Pln]")
plt.legend(["NOK"])
plt.grid()

plt.show()

# %%
SEK = requests.get("https://api.nbp.pl/api/exchangerates/rates/a/sek/2020-01-01/2020-06-11/")

sek_frame = pd.read_json(SEK.content)
sek_rates = sek_frame.rates
sek_list=[index['mid'] for index in sek_rates]
plt.plot(sek_list)
plt.xticks(rotation=45)
plt.title("Kurs Korony Szwedzkiej")
plt.xlabel("2020-01-01 do 2020-06-11")
plt.ylabel("Cena [Pln]")
plt.legend(["SEK"])
plt.grid()

# %%
SEK = requests.get("https://api.nbp.pl/api/exchangerates/rates/a/sek/2020-01-01/2020-06-11/")

sek_frame = pd.read_json(SEK.content)
sek_rates = sek_frame.rates
sek_list=[index['mid'] for index in sek_rates]
plt.plot(sek_list)
plt.xticks(rotation=45)
plt.title("Kurs Korony Szwedzkiej")
plt.xlabel("2020-01-01 do 2020-06-11")
plt.ylabel("Cena [Pln]")
plt.legend(["SEK"])
plt.grid()

plt.show()

# %% [markdown]
# # Podsumowanie

# %%
"""

Światowy krysys odbił się bardzo widocznie na światorym rynku walut. Na wszystkich wykresach, 
możemy zaobserwować wyraźny spadek pod koniec pierwszego kwartału. 

Na przykładzie Jena, Euro, bądź Franka Szwajcarkiego możemy dopatrzeć się odstępstwa od reguły, 
w którym to cena tych walut była od początku roku na niskim poziomie, a na końcu pierwszego kwartału 
podskoczyła.

Nadal nie wiem jak będą rysować się,
pozornie lepiej wyglądające wartości w trzecim i czwartym kwartale roku. 

Pomimo wielu spadków wartości, które pojawiły się w czasie "Lock downu" kurs walut ustabilizował się
we wszystkich badanych krajach. Cięzko jest przewidzieć jak rysować będą się te dane w najbliższym czasie. 


Z jednej strony czasowo zamknięte była większość zakładow, a znaczna cześć małych przedsiembiorców 
straciła klientów i stanęła na granicy bankructwa. 

Owy wirus z pewność przyczynił się również do 
przyrostu kapitału choćby dla ludzi parających się sprzedażą sprzętów medycznych. 

"""
